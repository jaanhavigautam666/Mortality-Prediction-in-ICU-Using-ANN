# %% [markdown]
# <a href="https://colab.research.google.com/github/jaanhavigautam666/Mortality-Prediction-in-ICU-Using-ANN/blob/main/Data_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
dataset_train = pd.read_csv('train.csv')
dataset_test = pd.read_csv('labels.csv')

# %%
dataset_train.head()
# Out:
#      ALP   ALT    AST  Age  ...       Urine        WBC     Weight        pH
# 0   77.0  31.0   46.0   54  ...  171.052632  10.300000  80.060976  7.387273
# 1   77.0  31.0   46.0   76  ...  151.560976  11.266667  80.670588  7.395000
# 2  116.0  83.0  199.5   44  ...  124.951220   4.700000  56.700000  7.495000
# 3  105.0  12.0   15.0   68  ...  545.833333   9.400000  84.600000  7.387273
# 4   77.0  31.0   46.0   88  ...   62.131579   4.300000  80.060976  7.387273
#
# [5 rows x 42 columns]

# %%
dataset_train.columns
# Out:
# Index(['ALP', 'ALT', 'AST', 'Age', 'Albumin', 'BUN', 'Bilirubin',
#        'Cholesterol', 'Creatinine', 'DiasABP', 'FiO2', 'GCS', 'Gender',
#        'Glucose', 'HCO3', 'HCT', 'HR', 'Height', 'ICUType', 'K', 'Lactate',
#        'MAP', 'MechVent', 'Mg', 'NIDiasABP', 'NIMAP', 'NISysABP', 'Na',
#        'PaCO2', 'PaO2', 'Platelets', 'RecordID', 'RespRate', 'SaO2', 'SysABP',
#        'Temp', 'TroponinI', 'TroponinT', 'Urine', 'WBC', 'Weight', 'pH'],
#       dtype='object')

# %%
dataset_train.shape
# Out:
# (3999, 42)

# %%
dataset_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 42 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ALP          3999 non-null   float64
#  1   ALT          3999 non-null   float64
#  2   AST          3999 non-null   float64
#  3   Age          3999 non-null   int64
#  4   Albumin      3999 non-null   float64
#  5   BUN          3999 non-null   float64
#  6   Bilirubin    3999 non-null   float64
#  7   Cholesterol  3999 non-null   float64
#  8   Creatinine   3999 non-null   float64
#  9   DiasABP      3999 non-null   float64
#  10  FiO2         3999 non-null   float64
#  11  GCS          3999 non-null   float64
#  12  Gender       3999 non-null   int64
#  13  Glucose      3999 non-null   float64
#  14  HCO3         3999 non-null   float64
#  15  HCT          3999 non-null   float64
#  16  HR           3999 non-null   float64
#  17  Height       3999 non-null   float64
# ...

# %%
dataset_train.describe()
# Out:
#                ALP          ALT  ...       Weight           pH
# count  3999.000000  3999.000000  ...  3999.000000  3999.000000
# mean     89.259978    91.709903  ...    82.799384     7.488870
# std      70.397850   427.290858  ...    23.117431     2.986373
# min      12.000000     3.000000  ...     3.500000     6.311667
# 25%      77.000000    31.000000  ...    68.201064     7.364142
# 50%      77.000000    31.000000  ...    80.060976     7.387273
# 75%      82.000000    32.250000  ...    93.040476     7.407500
# max    1472.333333  9143.428571  ...   300.000000   128.532500
#
# [8 rows x 42 columns]

# %%
dataset_test.shape
# Out:
# (3999, 1)

# %%
dataset_test["In-hospital_death"].value_counts()
# Out:
# 0    3445
# 1     554
# Name: In-hospital_death, dtype: int64

# %%
#One Hot Encoding
temp=[]
for i in dataset_test["In-hospital_death"]:
  if i==0:
    temp.append([1,0])
  else:
    temp.append([0,1])
temp= np.array(temp)

# %%
temp.shape
# Out:
# (3999, 2)

# %%
train_test= pd.concat([dataset_train,dataset_test],axis = 1)

# %%
train_test.shape
# Out:
# (3999, 43)
